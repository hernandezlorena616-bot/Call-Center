# %% [markdown]
# <a href="https://colab.research.google.com/github/hernandezlorena616-bot/Call-Center/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.1.2-py3-none-any.whl.metadata (6.2 kB)
# Downloading simpy-4.1.2-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.2

# %%
import simpy
import random

# Parámetros
TIEMPO_SIMULACION = 30
NUMERO_AGENTES = 2

clientes_llaman = 0
clientes_atendidos = 0

def atender_cliente(env, nombre, agentes):
    global clientes_atendidos

    print(f"[{env.now}] {nombre} está llamando.")

    with agentes.request() as solicitud:
        yield solicitud

        print(f"[{env.now}] {nombre} está siendo atendido.")

        tiempo = random.randint(2, 5)
        yield env.timeout(tiempo)

        clientes_atendidos += 1
        print(f"[{env.now}] {nombre} fue atendido.\n")

def generar_llamadas(env, agentes):
    global clientes_llaman

    numero = 1

    while True:
        espera = random.randint(1, 4)
        yield env.timeout(espera)

        clientes_llaman += 1
        env.process(
            atender_cliente(env, f"Cliente {numero}", agentes)
        )

        numero += 1

# Crear entorno
env = simpy.Environment()

# Crear recurso
agentes = simpy.Resource(env, capacity=NUMERO_AGENTES)

# Iniciar simulación
env.process(generar_llamadas(env, agentes))

# Ejecutar
env.run(until=TIEMPO_SIMULACION)

# Resumen
print("====================================")
print("RESUMEN DEL CALL CENTER")
print("====================================")
print("Tiempo de llamadas:", TIEMPO_SIMULACION, "minutos")
print("Número de clientes que llamaron:", clientes_llaman)
print("Número de clientes atendidos:", clientes_atendidos)
# Out:
# [1] Cliente 1 está llamando.
# [1] Cliente 1 está siendo atendido.
# [3] Cliente 2 está llamando.
# [3] Cliente 2 está siendo atendido.
# [4] Cliente 1 fue atendido.
#
# [4] Cliente 3 está llamando.
# [4] Cliente 3 está siendo atendido.
# [6] Cliente 4 está llamando.
# [7] Cliente 2 fue atendido.
#
# [7] Cliente 3 fue atendido.
#
# [7] Cliente 5 está llamando.
# [7] Cliente 4 está siendo atendido.
# [7] Cliente 5 está siendo atendido.
# [10] Cliente 4 fue atendido.
#
# [11] Cliente 6 está llamando.
# [11] Cliente 6 está siendo atendido.
# [12] Cliente 5 fue atendido.
#
# [12] Cliente 7 está llamando.
# [12] Cliente 7 está siendo atendido.
# [13] Cliente 8 está llamando.
# [15] Cliente 6 fue atendido.
#
# [15] Cliente 9 está llamando.
# [15] Cliente 8 está siendo atendido.
# [17] Cliente 7 fue atendido.
#
# [17] Cliente 9 está siendo atendido.
# [18] Cliente 10 está llamando.
# [20] Cliente 8 fue atendido.
#
# [20] Cliente 9 fue atendido.
#
# [20] Cliente 10 está siendo atendido.
# [21] Cliente 11 está llamando.
# [21] Cliente 11 está siendo atendido.
# [22] Cliente 10 fue atendido.
#
# [23] Cliente 12 está llamando.
# [23] Cliente 12 está siendo atendido.
# [25] Cliente 11 fue atendido.
#
# [26] Cliente 13 está llamando.
# [26] Cliente 13 está siendo atendido.
# [28] Cliente 12 fue atendido.
#
# [28] Cliente 13 fue atendido.
#
# [29] Cliente 14 está llamando.
# [29] Cliente 14 está siendo atendido.
# ====================================
# RESUMEN DEL CALL CENTER
# ====================================
# Tiempo de llamadas: 30 minutos
# Número de clientes que llamaron: 14
# Número de clientes atendidos: 13
